# %% [markdown]
# ## The jupyter to test whether the visualization routes are working

# %%
from local_host_tester import app

# %%
with open("test.html", "w") as file:
    file.write(app.get("/visualization").json()["figure_str"])

# %%
app.get("/visualization").json()
# Out:
# {'model_data': [{'free_available': True,
#    'model_id': 'alibaba/tongyi-deepresearch-30b-a3b:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 169886,
#    'tool_call_errors': 3719,
#    'total_completion_tokens': 191155192,
#    'total_native_reasoning_tokens': 157979883,
#    'total_prompt_tokens': 1144969815,
#    'total_tool_calls': 33273},
#   {'free_available': False,
#    'model_id': 'alibaba/tongyi-deepresearch-30b-a3b',
#    'pricing': {'completion': 4e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 9e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 169886,
#    'tool_call_errors': 3719,
#    'total_completion_tokens': 191155192,
#    'total_native_reasoning_tokens': 157979883,
#    'total_prompt_tokens': 1144969815,
#    'total_tool_calls': 33273},
#   {'free_available': False,
#    'model_id': 'amazon/nova-premier-v1',
#    'pricing': {'completion': 1.25e-05,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2.5e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 39615,
#    'tool_call_errors': 2,
#    'total_completion_tokens': 5621251,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 164383604,
#    'total_tool_calls': 1157},
#   {'free_available': False,
#    'model_id': 'amazon/nova-pro-v1',
#    'pricing': {'completion': 3.2e-06,
#     'image': 0.0012,
#     'internal_reasoning': 0.0,
#     'prompt': 8e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 17760,
#    'tool_call_errors': 1,
#    'total_completion_tokens': 3828682,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 67425074,
#    'total_tool_calls': 1363},
#   {'free_available': False,
#    'model_id': 'anthropic/claude-haiku-4.5',
#    'pricing': {'completion': 5e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 5377734,
#    'tool_call_errors': 47479,
#    'total_completion_tokens': 2729371715,
#    'total_native_reasoning_tokens': 155218031,
#    'total_prompt_tokens': 68494527678,
#    'total_tool_calls': 1273926},
#   {'free_available': False,
#    'model_id': 'anthropic/claude-sonnet-4.5',
#    'pricing': {'completion': 1.5e-05,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 15547406,
#    'tool_call_errors': 124775,
#    'total_completion_tokens': 11032452719,
#    'total_native_reasoning_tokens': 664370958,
#    'total_prompt_tokens': 531630355782,
#    'total_tool_calls': 4099282},
#   {'free_available': False,
#    'model_id': 'anthropic/claude-opus-4.1',
#    'pricing': {'completion': 7.5e-05,
#     'image': 0.024,
#     'internal_reasoning': 0.0,
#     'prompt': 1.5e-05,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 433434,
#    'tool_call_errors': 941,
#    'total_completion_tokens': 262305149,
#    'total_native_reasoning_tokens': 11145922,
#    'total_prompt_tokens': 8205492341,
#    'total_tool_calls': 59628},
#   {'free_available': False,
#    'model_id': 'anthropic/claude-opus-4',
#    'pricing': {'completion': 7.5e-05,
#     'image': 0.024,
#     'internal_reasoning': 0.0,
#     'prompt': 1.5e-05,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 163660,
#    'tool_call_errors': 604,
#    'total_completion_tokens': 72788543,
#    'total_native_reasoning_tokens': 1653019,
#    'total_prompt_tokens': 1753657483,
#    'total_tool_calls': 10977},
#   {'free_available': False,
#    'model_id': 'anthropic/claude-sonnet-4',
#    'pricing': {'completion': 1.5e-05,
#     'image': 0.0048,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 5734667,
#    'tool_call_errors': 18989,
#    'total_completion_tokens': 3236454437,
#    'total_native_reasoning_tokens': 72276497,
#    'total_prompt_tokens': 120011482275,
#    'total_tool_calls': 1530389},
#   {'free_available': False,
#    'model_id': 'anthropic/claude-3.7-sonnet:thinking',
#    'pricing': {'completion': 1.5e-05,
#     'image': 0.0048,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 5588673,
#    'tool_call_errors': 2193,
#    'total_completion_tokens': 2353857961,
#    'total_native_reasoning_tokens': 429760778,
#    'total_prompt_tokens': 34722127842,
#    'total_tool_calls': 135991},
#   {'free_available': False,
#    'model_id': 'anthropic/claude-3.7-sonnet',
#    'pricing': {'completion': 1.5e-05,
#     'image': 0.0048,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 5588673,
#    'tool_call_errors': 2193,
#    'total_completion_tokens': 2353857961,
#    'total_native_reasoning_tokens': 429760778,
#    'total_prompt_tokens': 34722127842,
#    'total_tool_calls': 135991},
#   {'free_available': False,
#    'model_id': 'anthropic/claude-3.5-haiku',
#    'pricing': {'completion': 4e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 8e-07,
#     'request': 0.0,
#     'web_search': 0.01},
#    'times_used': 2639741,
#    'tool_call_errors': 2621,
#    'total_completion_tokens': 587721591,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 13718792493,
#    'total_tool_calls': 386920},
#   {'free_available': False,
#    'model_id': 'anthropic/claude-3.5-sonnet',
#    'pricing': {'completion': 1.5e-05,
#     'image': 0.0048,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 1798680,
#    'tool_call_errors': 1109,
#    'total_completion_tokens': 454169411,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 7768126217,
#    'total_tool_calls': 89242},
#   {'free_available': False,
#    'model_id': 'anthropic/claude-3-haiku',
#    'pricing': {'completion': 1.25e-06,
#     'image': 0.0004,
#     'internal_reasoning': 0.0,
#     'prompt': 2.5e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 1463424,
#    'tool_call_errors': 3714,
#    'total_completion_tokens': 375851559,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 2928430079,
#    'total_tool_calls': 182349},
#   {'free_available': False,
#    'model_id': 'cohere/command-r-plus-08-2024',
#    'pricing': {'completion': 1e-05,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2.5e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 14376,
#    'tool_call_errors': 18,
#    'total_completion_tokens': 2605167,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 25829047,
#    'total_tool_calls': 1033},
#   {'free_available': False,
#    'model_id': 'deepseek/deepseek-v3.2-exp',
#    'pricing': {'completion': 3.28e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2.16e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 8273374,
#    'tool_call_errors': 14940,
#    'total_completion_tokens': 2838405874,
#    'total_native_reasoning_tokens': 487912164,
#    'total_prompt_tokens': 47681347172,
#    'total_tool_calls': 262399},
#   {'free_available': False,
#    'model_id': 'deepseek/deepseek-v3.1-terminus:exacto',
#    'pricing': {'completion': 8e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2.16e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 3951241,
#    'tool_call_errors': 17515,
#    'total_completion_tokens': 947642043,
#    'total_native_reasoning_tokens': 83508621,
#    'total_prompt_tokens': 21557397077,
#    'total_tool_calls': 163389},
#   {'free_available': False,
#    'model_id': 'deepseek/deepseek-v3.1-terminus',
#    'pricing': {'completion': 8e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2.16e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 3951241,
#    'tool_call_errors': 17515,
#    'total_completion_tokens': 947642043,
#    'total_native_reasoning_tokens': 83508621,
#    'total_prompt_tokens': 21557397077,
#    'total_tool_calls': 163389},
#   {'free_available': False,
#    'model_id': 'deepseek/deepseek-chat-v3.1',
#    'pricing': {'completion': 8e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 21139974,
#    'tool_call_errors': 53950,
#    'total_completion_tokens': 4920486820,
#    'total_native_reasoning_tokens': 293577409,
#    'total_prompt_tokens': 94225273328,
#    'total_tool_calls': 635706},
#   {'free_available': True,
#    'model_id': 'deepseek/deepseek-r1-0528:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 3209430,
#    'tool_call_errors': 167,
#    'total_completion_tokens': 4086055685,
#    'total_native_reasoning_tokens': 2930266376,
#    'total_prompt_tokens': 18939795711,
#    'total_tool_calls': 27747},
#   {'free_available': False,
#    'model_id': 'deepseek/deepseek-r1-0528',
#    'pricing': {'completion': 4.5e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 3209430,
#    'tool_call_errors': 167,
#    'total_completion_tokens': 4086055685,
#    'total_native_reasoning_tokens': 2930266376,
#    'total_prompt_tokens': 18939795711,
#    'total_tool_calls': 27747},
#   {'free_available': True,
#    'model_id': 'deepseek/deepseek-chat-v3-0324:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 25075913,
#    'tool_call_errors': 1431,
#    'total_completion_tokens': 5465647383,
#    'total_native_reasoning_tokens': 34495,
#    'total_prompt_tokens': 117579258305,
#    'total_tool_calls': 66932},
#   {'free_available': False,
#    'model_id': 'deepseek/deepseek-chat-v3-0324',
#    'pricing': {'completion': 8.96e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2.16e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 25075913,
#    'tool_call_errors': 1431,
#    'total_completion_tokens': 5465647383,
#    'total_native_reasoning_tokens': 34495,
#    'total_prompt_tokens': 117579258305,
#    'total_tool_calls': 66932},
#   {'free_available': True,
#    'model_id': 'deepseek/deepseek-r1:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 1143699,
#    'tool_call_errors': 223,
#    'total_completion_tokens': 1128769673,
#    'total_native_reasoning_tokens': 804298376,
#    'total_prompt_tokens': 4200275146,
#    'total_tool_calls': 4291},
#   {'free_available': False,
#    'model_id': 'deepseek/deepseek-r1',
#    'pricing': {'completion': 1.2e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 1143699,
#    'tool_call_errors': 223,
#    'total_completion_tokens': 1128769673,
#    'total_native_reasoning_tokens': 804298376,
#    'total_prompt_tokens': 4200275146,
#    'total_tool_calls': 4291},
#   {'free_available': False,
#    'model_id': 'deepseek/deepseek-chat',
#    'pricing': {'completion': 1.2e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 5458942,
#    'tool_call_errors': 2252,
#    'total_completion_tokens': 1513017919,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 11394834057,
#    'total_tool_calls': 193382},
#   {'free_available': False,
#    'model_id': 'google/gemini-3-pro-preview',
#    'pricing': {'completion': 1.2e-05,
#     'image': 0.008256,
#     'internal_reasoning': 0.0,
#     'prompt': 2e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 5387829,
#    'tool_call_errors': 6100,
#    'total_completion_tokens': 12049363862,
#    'total_native_reasoning_tokens': 8448485659,
#    'total_prompt_tokens': 159630269271,
#    'total_tool_calls': 206087},
#   {'free_available': False,
#    'model_id': 'google/gemini-2.5-flash-preview-09-2025',
#    'pricing': {'completion': 2.5e-06,
#     'image': 0.001238,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 8789120,
#    'tool_call_errors': 86454,
#    'total_completion_tokens': 5371883408,
#    'total_native_reasoning_tokens': 1582727775,
#    'total_prompt_tokens': 73412821748,
#    'total_tool_calls': 1732874},
#   {'free_available': False,
#    'model_id': 'google/gemini-2.5-flash-lite-preview-09-2025',
#    'pricing': {'completion': 4e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 31320617,
#    'tool_call_errors': 10057,
#    'total_completion_tokens': 13980959103,
#    'total_native_reasoning_tokens': 2204674045,
#    'total_prompt_tokens': 85691221566,
#    'total_tool_calls': 359464},
#   {'free_available': False,
#    'model_id': 'google/gemini-2.5-flash-lite',
#    'pricing': {'completion': 4e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 82771926,
#    'tool_call_errors': 94121,
#    'total_completion_tokens': 23396925022,
#    'total_native_reasoning_tokens': 1902179217,
#    'total_prompt_tokens': 142757404596,
#    'total_tool_calls': 2013989},
#   {'free_available': False,
#    'model_id': 'google/gemini-2.5-flash',
#    'pricing': {'completion': 2.5e-06,
#     'image': 0.001238,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 94030672,
#    'tool_call_errors': 222052,
#    'total_completion_tokens': 30502752446,
#    'total_native_reasoning_tokens': 7018896159,
#    'total_prompt_tokens': 369583819371,
#    'total_tool_calls': 6149825},
#   {'free_available': False,
#    'model_id': 'google/gemini-2.5-pro',
#    'pricing': {'completion': 1e-05,
#     'image': 0.00516,
#     'internal_reasoning': 0.0,
#     'prompt': 1.25e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 14509463,
#    'tool_call_errors': 41302,
#    'total_completion_tokens': 26574920349,
#    'total_native_reasoning_tokens': 17222552461,
#    'total_prompt_tokens': 142998987611,
#    'total_tool_calls': 1161427},
#   {'free_available': False,
#    'model_id': 'google/gemini-2.5-pro-preview',
#    'pricing': {'completion': 1e-05,
#     'image': 0.00516,
#     'internal_reasoning': 0.0,
#     'prompt': 1.25e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 14509463,
#    'tool_call_errors': 41302,
#    'total_completion_tokens': 26574920349,
#    'total_native_reasoning_tokens': 17222552461,
#    'total_prompt_tokens': 142998987611,
#    'total_tool_calls': 1161427},
#   {'free_available': False,
#    'model_id': 'google/gemini-2.5-pro-preview-05-06',
#    'pricing': {'completion': 1e-05,
#     'image': 0.00516,
#     'internal_reasoning': 0.0,
#     'prompt': 1.25e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 14509463,
#    'tool_call_errors': 41302,
#    'total_completion_tokens': 26574920349,
#    'total_native_reasoning_tokens': 17222552461,
#    'total_prompt_tokens': 142998987611,
#    'total_tool_calls': 1161427},
#   {'free_available': False,
#    'model_id': 'google/gemini-2.0-flash-lite-001',
#    'pricing': {'completion': 3e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 7.5e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 26579187,
#    'tool_call_errors': 12424,
#    'total_completion_tokens': 3183314030,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 25734503323,
#    'total_tool_calls': 1043392},
#   {'free_available': False,
#    'model_id': 'google/gemini-2.0-flash-001',
#    'pricing': {'completion': 4e-07,
#     'image': 2.58e-05,
#     'internal_reasoning': 0.0,
#     'prompt': 1e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 102123024,
#    'tool_call_errors': 80800,
#    'total_completion_tokens': 21755448097,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 181444755831,
#    'total_tool_calls': 3638098},
#   {'free_available': True,
#    'model_id': 'google/gemini-2.0-flash-exp:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 202972,
#    'tool_call_errors': 316,
#    'total_completion_tokens': 104413725,
#    'total_native_reasoning_tokens': 87,
#    'total_prompt_tokens': 1778820569,
#    'total_tool_calls': 2591},
#   {'free_available': False,
#    'model_id': 'inception/mercury-coder',
#    'pricing': {'completion': 1e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2.5e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 19924,
#    'tool_call_errors': 238,
#    'total_completion_tokens': 15950813,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 79360822,
#    'total_tool_calls': 1968},
#   {'free_available': True,
#    'model_id': 'kwaipilot/kat-coder-pro:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 1632535,
#    'tool_call_errors': 20420,
#    'total_completion_tokens': 966748207,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 54405332690,
#    'total_tool_calls': 329731},
#   {'free_available': False,
#    'model_id': 'meta-llama/llama-4-maverick',
#    'pricing': {'completion': 6.8e-07,
#     'image': 0.0006684,
#     'internal_reasoning': 0.0,
#     'prompt': 1.36e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 9136939,
#    'tool_call_errors': 3022,
#    'total_completion_tokens': 1280667440,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 16347462199,
#    'total_tool_calls': 276754},
#   {'free_available': False,
#    'model_id': 'meta-llama/llama-4-scout',
#    'pricing': {'completion': 3e-07,
#     'image': 0.0003342,
#     'internal_reasoning': 0.0,
#     'prompt': 8e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 7937683,
#    'tool_call_errors': 125,
#    'total_completion_tokens': 973591262,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 9370864064,
#    'total_tool_calls': 102571},
#   {'free_available': True,
#    'model_id': 'meta-llama/llama-3.3-70b-instruct:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 19646502,
#    'tool_call_errors': 3436,
#    'total_completion_tokens': 1740085579,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 17723591249,
#    'total_tool_calls': 38714},
#   {'free_available': False,
#    'model_id': 'meta-llama/llama-3.3-70b-instruct',
#    'pricing': {'completion': 3.12e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.04e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 19646502,
#    'tool_call_errors': 3436,
#    'total_completion_tokens': 1740085579,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 17723591249,
#    'total_tool_calls': 38714},
#   {'free_available': False,
#    'model_id': 'meta-llama/llama-3.1-70b-instruct',
#    'pricing': {'completion': 4e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 4e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 4625363,
#    'tool_call_errors': 147,
#    'total_completion_tokens': 319496814,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 5646796125,
#    'total_tool_calls': 1469},
#   {'free_available': False,
#    'model_id': 'meta-llama/llama-3.1-8b-instruct',
#    'pricing': {'completion': 3e-08,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 12467113,
#    'tool_call_errors': 3079,
#    'total_completion_tokens': 834189699,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 11757057109,
#    'total_tool_calls': 44450},
#   {'free_available': False,
#    'model_id': 'minimax/minimax-m2',
#    'pricing': {'completion': 9.6e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2.4e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 4904802,
#    'tool_call_errors': 332241,
#    'total_completion_tokens': 3603722900,
#    'total_native_reasoning_tokens': 1733846312,
#    'total_prompt_tokens': 214162896910,
#    'total_tool_calls': 2913953},
#   {'free_available': False,
#    'model_id': 'mistralai/voxtral-small-24b-2507',
#    'pricing': {'completion': 3e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 13578,
#    'tool_call_errors': 0,
#    'total_completion_tokens': 3018118,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 20522509,
#    'total_tool_calls': 1155},
#   {'free_available': False,
#    'model_id': 'mistralai/mistral-medium-3.1',
#    'pricing': {'completion': 2e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 4e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 379259,
#    'tool_call_errors': 545,
#    'total_completion_tokens': 146939712,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 2288734659,
#    'total_tool_calls': 18118},
#   {'free_available': False,
#    'model_id': 'mistralai/codestral-2508',
#    'pricing': {'completion': 9e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 431023,
#    'tool_call_errors': 340,
#    'total_completion_tokens': 104873892,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 2084840719,
#    'total_tool_calls': 5772},
#   {'free_available': False,
#    'model_id': 'mistralai/devstral-medium',
#    'pricing': {'completion': 2e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 4e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 86617,
#    'tool_call_errors': 18,
#    'total_completion_tokens': 116211320,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 232847115,
#    'total_tool_calls': 3779},
#   {'free_available': False,
#    'model_id': 'mistralai/devstral-small',
#    'pricing': {'completion': 2.8e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 7e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 1095273,
#    'tool_call_errors': 6,
#    'total_completion_tokens': 132950856,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 1385125397,
#    'total_tool_calls': 4943},
#   {'free_available': True,
#    'model_id': 'mistralai/mistral-small-3.2-24b-instruct:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 5604191,
#    'tool_call_errors': 1072,
#    'total_completion_tokens': 2486687084,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 14923596034,
#    'total_tool_calls': 18810},
#   {'free_available': False,
#    'model_id': 'mistralai/mistral-small-3.2-24b-instruct',
#    'pricing': {'completion': 1.8e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 6e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 5604191,
#    'tool_call_errors': 1072,
#    'total_completion_tokens': 2486687084,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 14923596034,
#    'total_tool_calls': 18810},
#   {'free_available': False,
#    'model_id': 'mistralai/devstral-small-2505',
#    'pricing': {'completion': 1.2e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 6e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 69143,
#    'tool_call_errors': 10,
#    'total_completion_tokens': 20224132,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 75150810,
#    'total_tool_calls': 1930},
#   {'free_available': True,
#    'model_id': 'mistralai/mistral-small-3.1-24b-instruct:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 817151,
#    'tool_call_errors': 775,
#    'total_completion_tokens': 174572965,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 2957101143,
#    'total_tool_calls': 13531},
#   {'free_available': False,
#    'model_id': 'mistralai/mistral-small-3.1-24b-instruct',
#    'pricing': {'completion': 1.1e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 817151,
#    'tool_call_errors': 775,
#    'total_completion_tokens': 174572965,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 2957101143,
#    'total_tool_calls': 13531},
#   {'free_available': False,
#    'model_id': 'mistralai/codestral-2501',
#    'pricing': {'completion': 9e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 86820,
#    'tool_call_errors': 17,
#    'total_completion_tokens': 25249058,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 58816804,
#    'total_tool_calls': 1101},
#   {'free_available': False,
#    'model_id': 'mistralai/mistral-large-2411',
#    'pricing': {'completion': 6e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 705719,
#    'tool_call_errors': 866,
#    'total_completion_tokens': 211781907,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 2185860298,
#    'total_tool_calls': 390922},
#   {'free_available': False,
#    'model_id': 'mistralai/mistral-large-2407',
#    'pricing': {'completion': 6e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 100021,
#    'tool_call_errors': 9388,
#    'total_completion_tokens': 130866916,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 470338685,
#    'total_tool_calls': 49521},
#   {'free_available': False,
#    'model_id': 'mistralai/ministral-8b',
#    'pricing': {'completion': 1e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 1101849,
#    'tool_call_errors': 72,
#    'total_completion_tokens': 265411166,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 623747278,
#    'total_tool_calls': 2478},
#   {'free_available': True,
#    'model_id': 'mistralai/mistral-nemo:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 29295329,
#    'tool_call_errors': 208,
#    'total_completion_tokens': 2807478069,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 68998049075,
#    'total_tool_calls': 3700},
#   {'free_available': False,
#    'model_id': 'mistralai/mistral-nemo',
#    'pricing': {'completion': 4e-08,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 29295329,
#    'tool_call_errors': 208,
#    'total_completion_tokens': 2807478069,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 68998049075,
#    'total_tool_calls': 3700},
#   {'free_available': False,
#    'model_id': 'mistralai/mistral-large',
#    'pricing': {'completion': 6e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 140296,
#    'tool_call_errors': 151,
#    'total_completion_tokens': 23730286,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 161337338,
#    'total_tool_calls': 1117},
#   {'free_available': False,
#    'model_id': 'moonshotai/kimi-k2-thinking',
#    'pricing': {'completion': 2.35e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 4.5e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 2053433,
#    'tool_call_errors': 8150,
#    'total_completion_tokens': 2800037827,
#    'total_native_reasoning_tokens': 2212874720,
#    'total_prompt_tokens': 24973741561,
#    'total_tool_calls': 719222},
#   {'free_available': False,
#    'model_id': 'moonshotai/kimi-k2-0905',
#    'pricing': {'completion': 1.9e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3.9e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 4634563,
#    'tool_call_errors': 1288,
#    'total_completion_tokens': 886125704,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 10117954499,
#    'total_tool_calls': 196517},
#   {'free_available': False,
#    'model_id': 'moonshotai/kimi-k2-0905:exacto',
#    'pricing': {'completion': 2.5e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 6e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 4634563,
#    'tool_call_errors': 1288,
#    'total_completion_tokens': 886125704,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 10117954499,
#    'total_tool_calls': 196517},
#   {'free_available': True,
#    'model_id': 'moonshotai/kimi-k2:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 2086345,
#    'tool_call_errors': 388,
#    'total_completion_tokens': 1167783434,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 7958638472,
#    'total_tool_calls': 43505},
#   {'free_available': False,
#    'model_id': 'moonshotai/kimi-k2',
#    'pricing': {'completion': 1.84e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 4.56e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 2086345,
#    'tool_call_errors': 388,
#    'total_completion_tokens': 1167783434,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 7958638472,
#    'total_tool_calls': 43505},
#   {'free_available': False,
#    'model_id': 'nvidia/llama-3.3-nemotron-super-49b-v1.5',
#    'pricing': {'completion': 4e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 97163,
#    'tool_call_errors': 43,
#    'total_completion_tokens': 103589416,
#    'total_native_reasoning_tokens': 89541595,
#    'total_prompt_tokens': 500216252,
#    'total_tool_calls': 3664},
#   {'free_available': True,
#    'model_id': 'nvidia/nemotron-nano-9b-v2:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 1211421,
#    'tool_call_errors': 1138513,
#    'total_completion_tokens': 2337823322,
#    'total_native_reasoning_tokens': 827686933,
#    'total_prompt_tokens': 3211837475,
#    'total_tool_calls': 1139951},
#   {'free_available': False,
#    'model_id': 'nvidia/nemotron-nano-9b-v2',
#    'pricing': {'completion': 1.6e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 4e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 1211421,
#    'tool_call_errors': 1138513,
#    'total_completion_tokens': 2337823322,
#    'total_native_reasoning_tokens': 827686933,
#    'total_prompt_tokens': 3211837475,
#    'total_tool_calls': 1139951},
#   {'free_available': False,
#    'model_id': 'openai/gpt-5.1',
#    'pricing': {'completion': 1e-05,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.25e-06,
#     'request': 0.0,
#     'web_search': 0.01},
#    'times_used': 4067181,
#    'tool_call_errors': 6162,
#    'total_completion_tokens': 3364404723,
#    'total_native_reasoning_tokens': 1810711691,
#    'total_prompt_tokens': 46674565415,
#    'total_tool_calls': 342757},
#   {'free_available': False,
#    'model_id': 'openai/gpt-5.1-chat',
#    'pricing': {'completion': 1e-05,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.25e-06,
#     'request': 0.0,
#     'web_search': 0.01},
#    'times_used': 438362,
#    'tool_call_errors': 26,
#    'total_completion_tokens': 95248600,
#    'total_native_reasoning_tokens': 18627072,
#    'total_prompt_tokens': 1698129194,
#    'total_tool_calls': 16679},
#   {'free_available': False,
#    'model_id': 'openai/gpt-5.1-codex',
#    'pricing': {'completion': 1e-05,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.25e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 428838,
#    'tool_call_errors': 4044,
#    'total_completion_tokens': 366501032,
#    'total_native_reasoning_tokens': 232735104,
#    'total_prompt_tokens': 21940375714,
#    'total_tool_calls': 283562},
#   {'free_available': False,
#    'model_id': 'openai/gpt-5.1-codex-mini',
#    'pricing': {'completion': 2e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2.5e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 387507,
#    'tool_call_errors': 819,
#    'total_completion_tokens': 546118468,
#    'total_native_reasoning_tokens': 459580672,
#    'total_prompt_tokens': 8679315306,
#    'total_tool_calls': 106385},
#   {'free_available': False,
#    'model_id': 'openai/gpt-oss-safeguard-20b',
#    'pricing': {'completion': 3e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 7.5e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 2178516,
#    'tool_call_errors': 0,
#    'total_completion_tokens': 585964625,
#    'total_native_reasoning_tokens': 482231025,
#    'total_prompt_tokens': 3690455456,
#    'total_tool_calls': 29342},
#   {'free_available': False,
#    'model_id': 'openai/gpt-5-image',
#    'pricing': {'completion': 1e-05,
#     'image': 1e-05,
#     'internal_reasoning': 0.0,
#     'prompt': 1e-05,
#     'request': 0.0,
#     'web_search': 0.01},
#    'times_used': 42182,
#    'tool_call_errors': 0,
#    'total_completion_tokens': 87846084,
#    'total_native_reasoning_tokens': 67590656,
#    'total_prompt_tokens': 155816763,
#    'total_tool_calls': 10612},
#   {'free_available': False,
#    'model_id': 'openai/gpt-5-pro',
#    'pricing': {'completion': 0.00012,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.5e-05,
#     'request': 0.0,
#     'web_search': 0.01},
#    'times_used': 21028,
#    'tool_call_errors': 94,
#    'total_completion_tokens': 47486136,
#    'total_native_reasoning_tokens': 39002112,
#    'total_prompt_tokens': 345667566,
#    'total_tool_calls': 2779},
#   {'free_available': False,
#    'model_id': 'openai/gpt-5-codex',
#    'pricing': {'completion': 1e-05,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.25e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 128928,
#    'tool_call_errors': 1191,
#    'total_completion_tokens': 107106273,
#    'total_native_reasoning_tokens': 76187200,
#    'total_prompt_tokens': 5176203842,
#    'total_tool_calls': 85141},
#   {'free_available': False,
#    'model_id': 'openai/gpt-5',
#    'pricing': {'completion': 1e-05,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.25e-06,
#     'request': 0.0,
#     'web_search': 0.01},
#    'times_used': 5416838,
#    'tool_call_errors': 1431,
#    'total_completion_tokens': 8051192184,
#    'total_native_reasoning_tokens': 6065939200,
#    'total_prompt_tokens': 59128857589,
#    'total_tool_calls': 646623},
#   {'free_available': False,
#    'model_id': 'openai/gpt-5-mini',
#    'pricing': {'completion': 2e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2.5e-07,
#     'request': 0.0,
#     'web_search': 0.01},
#    'times_used': 11216529,
#    'tool_call_errors': 6002,
#    'total_completion_tokens': 11956365192,
#    'total_native_reasoning_tokens': 7735575104,
#    'total_prompt_tokens': 89314710943,
#    'total_tool_calls': 1618836},
#   {'free_available': False,
#    'model_id': 'openai/gpt-5-nano',
#    'pricing': {'completion': 4e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 5e-08,
#     'request': 0.0,
#     'web_search': 0.01},
#    'times_used': 7123170,
#    'tool_call_errors': 1988,
#    'total_completion_tokens': 5196515255,
#    'total_native_reasoning_tokens': 4451478272,
#    'total_prompt_tokens': 16165702257,
#    'total_tool_calls': 110522},
#   {'free_available': False,
#    'model_id': 'openai/gpt-oss-120b:exacto',
#    'pricing': {'completion': 2e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 4e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 15410465,
#    'tool_call_errors': 15729,
#    'total_completion_tokens': 9140357198,
#    'total_native_reasoning_tokens': 5960069163,
#    'total_prompt_tokens': 56607098651,
#    'total_tool_calls': 683435},
#   {'free_available': False,
#    'model_id': 'openai/gpt-oss-120b',
#    'pricing': {'completion': 2e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 4e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 15410465,
#    'tool_call_errors': 15729,
#    'total_completion_tokens': 9140357198,
#    'total_native_reasoning_tokens': 5960069163,
#    'total_prompt_tokens': 56607098651,
#    'total_tool_calls': 683435},
#   {'free_available': True,
#    'model_id': 'openai/gpt-oss-20b:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 12299675,
#    'tool_call_errors': 31019,
#    'total_completion_tokens': 13023445961,
#    'total_native_reasoning_tokens': 10084038201,
#    'total_prompt_tokens': 22857500774,
#    'total_tool_calls': 244485},
#   {'free_available': False,
#    'model_id': 'openai/gpt-oss-20b',
#    'pricing': {'completion': 1.4e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 12299675,
#    'tool_call_errors': 31019,
#    'total_completion_tokens': 13023445961,
#    'total_native_reasoning_tokens': 10084038201,
#    'total_prompt_tokens': 22857500774,
#    'total_tool_calls': 244485},
#   {'free_available': False,
#    'model_id': 'openai/o4-mini-high',
#    'pricing': {'completion': 4.4e-06,
#     'image': 0.0008415,
#     'internal_reasoning': 0.0,
#     'prompt': 1.1e-06,
#     'request': 0.0,
#     'web_search': 0.01},
#    'times_used': 124448,
#    'tool_call_errors': 700,
#    'total_completion_tokens': 166416545,
#    'total_native_reasoning_tokens': 132921920,
#    'total_prompt_tokens': 433917835,
#    'total_tool_calls': 19258},
#   {'free_available': False,
#    'model_id': 'openai/o3',
#    'pricing': {'completion': 8e-06,
#     'image': 0.00153,
#     'internal_reasoning': 0.0,
#     'prompt': 2e-06,
#     'request': 0.0,
#     'web_search': 0.01},
#    'times_used': 227369,
#    'tool_call_errors': 55,
#    'total_completion_tokens': 168177668,
#    'total_native_reasoning_tokens': 113251776,
#    'total_prompt_tokens': 904978090,
#    'total_tool_calls': 19507},
#   {'free_available': False,
#    'model_id': 'openai/o4-mini',
#    'pricing': {'completion': 4.4e-06,
#     'image': 0.0008415,
#     'internal_reasoning': 0.0,
#     'prompt': 1.1e-06,
#     'request': 0.0,
#     'web_search': 0.01},
#    'times_used': 414285,
#    'tool_call_errors': 55,
#    'total_completion_tokens': 372314943,
#    'total_native_reasoning_tokens': 288556608,
#    'total_prompt_tokens': 1246631632,
#    'total_tool_calls': 22279},
#   {'free_available': False,
#    'model_id': 'openai/gpt-4.1',
#    'pricing': {'completion': 8e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2e-06,
#     'request': 0.0,
#     'web_search': 0.01},
#    'times_used': 6040142,
#    'tool_call_errors': 3540,
#    'total_completion_tokens': 1356266168,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 28117717268,
#    'total_tool_calls': 634546},
#   {'free_available': False,
#    'model_id': 'openai/gpt-4.1-mini',
#    'pricing': {'completion': 1.6e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 4e-07,
#     'request': 0.0,
#     'web_search': 0.01},
#    'times_used': 26282525,
#    'tool_call_errors': 5623,
#    'total_completion_tokens': 5239627001,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 94991068929,
#    'total_tool_calls': 1368833},
#   {'free_available': False,
#    'model_id': 'openai/gpt-4.1-nano',
#    'pricing': {'completion': 4e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1e-07,
#     'request': 0.0,
#     'web_search': 0.01},
#    'times_used': 9500457,
#    'tool_call_errors': 23034,
#    'total_completion_tokens': 1338452215,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 19894309232,
#    'total_tool_calls': 678853},
#   {'free_available': False,
#    'model_id': 'openai/o3-mini-high',
#    'pricing': {'completion': 4.4e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.1e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 16319,
#    'tool_call_errors': 0,
#    'total_completion_tokens': 20733949,
#    'total_native_reasoning_tokens': 11085120,
#    'total_prompt_tokens': 96921597,
#    'total_tool_calls': 1183},
#   {'free_available': False,
#    'model_id': 'openai/o3-mini',
#    'pricing': {'completion': 4.4e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.1e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 489118,
#    'tool_call_errors': 44,
#    'total_completion_tokens': 499425986,
#    'total_native_reasoning_tokens': 362119168,
#    'total_prompt_tokens': 746742008,
#    'total_tool_calls': 3383},
#   {'free_available': False,
#    'model_id': 'openai/gpt-4o-2024-11-20',
#    'pricing': {'completion': 1e-05,
#     'image': 0.003613,
#     'internal_reasoning': 0.0,
#     'prompt': 2.5e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 1430700,
#    'tool_call_errors': 140,
#    'total_completion_tokens': 168614003,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 1563237707,
#    'total_tool_calls': 28784},
#   {'free_available': False,
#    'model_id': 'openai/gpt-4o-2024-08-06',
#    'pricing': {'completion': 1e-05,
#     'image': 0.003613,
#     'internal_reasoning': 0.0,
#     'prompt': 2.5e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 2046741,
#    'tool_call_errors': 210,
#    'total_completion_tokens': 322407982,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 1593632662,
#    'total_tool_calls': 27340},
#   {'free_available': False,
#    'model_id': 'openai/gpt-4o-mini-2024-07-18',
#    'pricing': {'completion': 6e-07,
#     'image': 0.007225,
#     'internal_reasoning': 0.0,
#     'prompt': 1.5e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 2893368,
#    'tool_call_errors': 251,
#    'total_completion_tokens': 359439370,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 7209195308,
#    'total_tool_calls': 14627},
#   {'free_available': False,
#    'model_id': 'openai/gpt-4o-mini',
#    'pricing': {'completion': 6e-07,
#     'image': 0.000217,
#     'internal_reasoning': 0.0,
#     'prompt': 1.5e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 53860624,
#    'tool_call_errors': 133454,
#    'total_completion_tokens': 6759017483,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 82206343456,
#    'total_tool_calls': 10596796},
#   {'free_available': False,
#    'model_id': 'openai/gpt-4o-2024-05-13',
#    'pricing': {'completion': 1.5e-05,
#     'image': 0.007225,
#     'internal_reasoning': 0.0,
#     'prompt': 5e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 18322,
#    'tool_call_errors': 1,
#    'total_completion_tokens': 1929630,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 46075717,
#    'total_tool_calls': 3445},
#   {'free_available': False,
#    'model_id': 'openai/gpt-4o',
#    'pricing': {'completion': 1e-05,
#     'image': 0.003613,
#     'internal_reasoning': 0.0,
#     'prompt': 2.5e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 6390001,
#    'tool_call_errors': 12751,
#    'total_completion_tokens': 977375466,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 11964047542,
#    'total_tool_calls': 950466},
#   {'free_available': False,
#    'model_id': 'openai/gpt-4o:extended',
#    'pricing': {'completion': 1.8e-05,
#     'image': 0.007225,
#     'internal_reasoning': 0.0,
#     'prompt': 6e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 6390001,
#    'tool_call_errors': 12751,
#    'total_completion_tokens': 977375466,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 11964047542,
#    'total_tool_calls': 950466},
#   {'free_available': False,
#    'model_id': 'openai/gpt-4-turbo',
#    'pricing': {'completion': 3e-05,
#     'image': 0.01445,
#     'internal_reasoning': 0.0,
#     'prompt': 1e-05,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 112421,
#    'tool_call_errors': 245,
#    'total_completion_tokens': 18918909,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 180973348,
#    'total_tool_calls': 2204},
#   {'free_available': False,
#    'model_id': 'openai/gpt-4-1106-preview',
#    'pricing': {'completion': 3e-05,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1e-05,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 28404,
#    'tool_call_errors': 0,
#    'total_completion_tokens': 3592160,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 25019106,
#    'total_tool_calls': 8105},
#   {'free_available': False,
#    'model_id': 'openai/gpt-4',
#    'pricing': {'completion': 6e-05,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-05,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 89313,
#    'tool_call_errors': 152,
#    'total_completion_tokens': 17651232,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 72887606,
#    'total_tool_calls': 2845},
#   {'free_available': False,
#    'model_id': 'openai/gpt-3.5-turbo',
#    'pricing': {'completion': 1.5e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 5e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 778071,
#    'tool_call_errors': 905,
#    'total_completion_tokens': 74380639,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 419232469,
#    'total_tool_calls': 15432},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-vl-8b-instruct',
#    'pricing': {'completion': 4e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 6.4e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 2920180,
#    'tool_call_errors': 184,
#    'total_completion_tokens': 386811172,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 6634189977,
#    'total_tool_calls': 2630},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-vl-30b-a3b-thinking',
#    'pricing': {'completion': 8e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.6e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 40518,
#    'tool_call_errors': 155,
#    'total_completion_tokens': 83827330,
#    'total_native_reasoning_tokens': 72052123,
#    'total_prompt_tokens': 123240206,
#    'total_tool_calls': 2232},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-vl-30b-a3b-instruct',
#    'pricing': {'completion': 6e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.5e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 2182444,
#    'tool_call_errors': 20531,
#    'total_completion_tokens': 420304904,
#    'total_native_reasoning_tokens': 67,
#    'total_prompt_tokens': 1884604188,
#    'total_tool_calls': 117030},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-vl-235b-a22b-instruct',
#    'pricing': {'completion': 1.9e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2.1e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 2850045,
#    'tool_call_errors': 6036,
#    'total_completion_tokens': 467540234,
#    'total_native_reasoning_tokens': 566773,
#    'total_prompt_tokens': 20283365778,
#    'total_tool_calls': 28280},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-max',
#    'pricing': {'completion': 6e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.2e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 377858,
#    'tool_call_errors': 14119,
#    'total_completion_tokens': 224087714,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 2575341588,
#    'total_tool_calls': 31431},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-coder-plus',
#    'pricing': {'completion': 5e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 65330,
#    'tool_call_errors': 446,
#    'total_completion_tokens': 22691996,
# ...
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 253252794,
#    'total_tool_calls': 13717},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-next-80b-a3b-thinking',
#    'pricing': {'completion': 1.2e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.2e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 178487,
#    'tool_call_errors': 343,
#    'total_completion_tokens': 656685747,
#    'total_native_reasoning_tokens': 572301668,
#    'total_prompt_tokens': 581343833,
#    'total_tool_calls': 20586},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-next-80b-a3b-instruct',
#    'pricing': {'completion': 8e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 4464073,
#    'tool_call_errors': 4640,
#    'total_completion_tokens': 523379469,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 14756898344,
#    'total_tool_calls': 113624},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-30b-a3b-thinking-2507',
#    'pricing': {'completion': 3.4e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 5.1e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 98365,
#    'tool_call_errors': 783,
#    'total_completion_tokens': 221495728,
#    'total_native_reasoning_tokens': 196605836,
#    'total_prompt_tokens': 649320625,
#    'total_tool_calls': 5942},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-coder-30b-a3b-instruct',
#    'pricing': {'completion': 2.5e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 6e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 20295130,
#    'tool_call_errors': 20995,
#    'total_completion_tokens': 43324235361,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 59107985464,
#    'total_tool_calls': 70138},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-30b-a3b-instruct-2507',
#    'pricing': {'completion': 3.3e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 8e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 1267922,
#    'tool_call_errors': 864,
#    'total_completion_tokens': 710744936,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 3148032982,
#    'total_tool_calls': 14735},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-235b-a22b-thinking-2507',
#    'pricing': {'completion': 6e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.1e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 673013,
#    'tool_call_errors': 4547,
#    'total_completion_tokens': 1582369919,
#    'total_native_reasoning_tokens': 1284412370,
#    'total_prompt_tokens': 2803076279,
#    'total_tool_calls': 96289},
#   {'free_available': True,
#    'model_id': 'qwen/qwen3-coder:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 4136917,
#    'tool_call_errors': 16619,
#    'total_completion_tokens': 3746072461,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 31348405766,
#    'total_tool_calls': 385444},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-coder',
#    'pricing': {'completion': 9.5e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2.2e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 4136917,
#    'tool_call_errors': 16619,
#    'total_completion_tokens': 3746072461,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 31348405766,
#    'total_tool_calls': 385444},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-coder:exacto',
#    'pricing': {'completion': 4e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 4136917,
#    'tool_call_errors': 16619,
#    'total_completion_tokens': 3746072461,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 31348405766,
#    'total_tool_calls': 385444},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-235b-a22b-2507',
#    'pricing': {'completion': 4.64e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 7.2e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 17762283,
#    'tool_call_errors': 20303,
#    'total_completion_tokens': 6056510781,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 76026673808,
#    'total_tool_calls': 608392},
#   {'free_available': True,
#    'model_id': 'qwen/qwen3-30b-a3b:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 1952269,
#    'tool_call_errors': 295,
#    'total_completion_tokens': 1305104785,
#    'total_native_reasoning_tokens': 1297237905,
#    'total_prompt_tokens': 4586055268,
#    'total_tool_calls': 5011},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-30b-a3b',
#    'pricing': {'completion': 2.2e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 6e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 1952269,
#    'tool_call_errors': 295,
#    'total_completion_tokens': 1305104785,
#    'total_native_reasoning_tokens': 1297237905,
#    'total_prompt_tokens': 4586055268,
#    'total_tool_calls': 5011},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-8b',
#    'pricing': {'completion': 1.104e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2.8e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 686820,
#    'tool_call_errors': 444,
#    'total_completion_tokens': 700234971,
#    'total_native_reasoning_tokens': 651829280,
#    'total_prompt_tokens': 969233460,
#    'total_tool_calls': 12063},
#   {'free_available': True,
#    'model_id': 'qwen/qwen3-14b:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 2273540,
#    'tool_call_errors': 278,
#    'total_completion_tokens': 1753324018,
#    'total_native_reasoning_tokens': 415906454,
#    'total_prompt_tokens': 3249449708,
#    'total_tool_calls': 7667},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-14b',
#    'pricing': {'completion': 2.2e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 5e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 2273540,
#    'tool_call_errors': 278,
#    'total_completion_tokens': 1753324018,
#    'total_native_reasoning_tokens': 415906454,
#    'total_prompt_tokens': 3249449708,
#    'total_tool_calls': 7667},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-32b',
#    'pricing': {'completion': 2.4e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 8e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 12769983,
#    'tool_call_errors': 4127,
#    'total_completion_tokens': 1357637921,
#    'total_native_reasoning_tokens': 902407776,
#    'total_prompt_tokens': 9528114669,
#    'total_tool_calls': 467549},
#   {'free_available': True,
#    'model_id': 'qwen/qwen3-235b-a22b:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 857642,
#    'tool_call_errors': 349,
#    'total_completion_tokens': 489485824,
#    'total_native_reasoning_tokens': 343983678,
#    'total_prompt_tokens': 3061282574,
#    'total_tool_calls': 8437},
#   {'free_available': False,
#    'model_id': 'qwen/qwen3-235b-a22b',
#    'pricing': {'completion': 5.4e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.8e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 857642,
#    'tool_call_errors': 349,
#    'total_completion_tokens': 489485824,
#    'total_native_reasoning_tokens': 343983678,
#    'total_prompt_tokens': 3061282574,
#    'total_tool_calls': 8437},
#   {'free_available': False,
#    'model_id': 'qwen/qwen-turbo',
#    'pricing': {'completion': 2e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 5e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 129522,
#    'tool_call_errors': 64,
#    'total_completion_tokens': 33287655,
#    'total_native_reasoning_tokens': 134075,
#    'total_prompt_tokens': 812858409,
#    'total_tool_calls': 13929},
#   {'free_available': False,
#    'model_id': 'qwen/qwen-plus',
#    'pricing': {'completion': 1.2e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 4e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 66365,
#    'tool_call_errors': 215,
#    'total_completion_tokens': 22256565,
#    'total_native_reasoning_tokens': 60472,
#    'total_prompt_tokens': 167474052,
#    'total_tool_calls': 4458},
#   {'free_available': True,
#    'model_id': 'qwen/qwen-2.5-72b-instruct:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 4296930,
#    'tool_call_errors': 3439,
#    'total_completion_tokens': 318560788,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 9961685991,
#    'total_tool_calls': 29857},
#   {'free_available': False,
#    'model_id': 'qwen/qwen-2.5-72b-instruct',
#    'pricing': {'completion': 2.6e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 7e-08,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 4296930,
#    'tool_call_errors': 3439,
#    'total_completion_tokens': 318560788,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 9961685991,
#    'total_tool_calls': 29857},
#   {'free_available': False,
#    'model_id': 'x-ai/grok-4.1-fast',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 66900638,
#    'tool_call_errors': 3774,
#    'total_completion_tokens': 104056620655,
#    'total_native_reasoning_tokens': 70754058409,
#    'total_prompt_tokens': 345841919029,
#    'total_tool_calls': 1082018},
#   {'free_available': True,
#    'model_id': 'x-ai/grok-4.1-fast:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 66900638,
#    'tool_call_errors': 3774,
#    'total_completion_tokens': 104056620655,
#    'total_native_reasoning_tokens': 70754058409,
#    'total_prompt_tokens': 345841919029,
#    'total_tool_calls': 1082018},
#   {'free_available': False,
#    'model_id': 'x-ai/grok-4-fast',
#    'pricing': {'completion': 5e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 27286855,
#    'tool_call_errors': 8035,
#    'total_completion_tokens': 22896451323,
#    'total_native_reasoning_tokens': 13012236821,
#    'total_prompt_tokens': 153502526494,
#    'total_tool_calls': 1188283},
#   {'free_available': False,
#    'model_id': 'x-ai/grok-code-fast-1',
#    'pricing': {'completion': 1.5e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 2e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 35221771,
#    'tool_call_errors': 14380,
#    'total_completion_tokens': 26836946666,
#    'total_native_reasoning_tokens': 11722496921,
#    'total_prompt_tokens': 1312382621796,
#    'total_tool_calls': 421967},
#   {'free_available': False,
#    'model_id': 'x-ai/grok-4',
#    'pricing': {'completion': 1.5e-05,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 968366,
#    'tool_call_errors': 1530,
#    'total_completion_tokens': 1502867343,
#    'total_native_reasoning_tokens': 1030249590,
#    'total_prompt_tokens': 10081101078,
#    'total_tool_calls': 212567},
#   {'free_available': False,
#    'model_id': 'x-ai/grok-3-mini',
#    'pricing': {'completion': 5e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 5695993,
#    'tool_call_errors': 10566,
#    'total_completion_tokens': 4197545846,
#    'total_native_reasoning_tokens': 3621132085,
#    'total_prompt_tokens': 11903195203,
#    'total_tool_calls': 41554},
#   {'free_available': False,
#    'model_id': 'x-ai/grok-3',
#    'pricing': {'completion': 1.5e-05,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 670316,
#    'tool_call_errors': 3,
#    'total_completion_tokens': 197775765,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 2002756739,
#    'total_tool_calls': 19225},
#   {'free_available': False,
#    'model_id': 'x-ai/grok-3-mini-beta',
#    'pricing': {'completion': 5e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 5695993,
#    'tool_call_errors': 10566,
#    'total_completion_tokens': 4197545846,
#    'total_native_reasoning_tokens': 3621132085,
#    'total_prompt_tokens': 11903195203,
#    'total_tool_calls': 41554},
#   {'free_available': False,
#    'model_id': 'x-ai/grok-3-beta',
#    'pricing': {'completion': 1.5e-05,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3e-06,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 670316,
#    'tool_call_errors': 3,
#    'total_completion_tokens': 197775765,
#    'total_native_reasoning_tokens': 0,
#    'total_prompt_tokens': 2002756739,
#    'total_tool_calls': 19225},
#   {'free_available': False,
#    'model_id': 'z-ai/glm-4.6',
#    'pricing': {'completion': 1.75e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 4e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 12766380,
#    'tool_call_errors': 42116,
#    'total_completion_tokens': 4445071554,
#    'total_native_reasoning_tokens': 1712211149,
#    'total_prompt_tokens': 100630696482,
#    'total_tool_calls': 8076431},
#   {'free_available': False,
#    'model_id': 'z-ai/glm-4.6:exacto',
#    'pricing': {'completion': 1.9e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 4.5e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 12766380,
#    'tool_call_errors': 42116,
#    'total_completion_tokens': 4445071554,
#    'total_native_reasoning_tokens': 1712211149,
#    'total_prompt_tokens': 100630696482,
#    'total_tool_calls': 8076431},
#   {'free_available': False,
#    'model_id': 'z-ai/glm-4.5v',
#    'pricing': {'completion': 1.44e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 4.8e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 117456,
#    'tool_call_errors': 364,
#    'total_completion_tokens': 29980418,
#    'total_native_reasoning_tokens': 18950581,
#    'total_prompt_tokens': 318960769,
#    'total_tool_calls': 4817},
#   {'free_available': False,
#    'model_id': 'z-ai/glm-4.5',
#    'pricing': {'completion': 1.5e-06,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 3.5e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 693747,
#    'tool_call_errors': 3349,
#    'total_completion_tokens': 624036726,
#    'total_native_reasoning_tokens': 186404571,
#    'total_prompt_tokens': 11382283987,
#    'total_tool_calls': 186509},
#   {'free_available': True,
#    'model_id': 'z-ai/glm-4.5-air:free',
#    'pricing': {'completion': 0.0,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 0.0,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 3125254,
#    'tool_call_errors': 3613,
#    'total_completion_tokens': 1220120548,
#    'total_native_reasoning_tokens': 443505760,
#    'total_prompt_tokens': 20901700460,
#    'total_tool_calls': 175966},
#   {'free_available': False,
#    'model_id': 'z-ai/glm-4.5-air',
#    'pricing': {'completion': 6.8e-07,
#     'image': 0.0,
#     'internal_reasoning': 0.0,
#     'prompt': 1.04e-07,
#     'request': 0.0,
#     'web_search': 0.0},
#    'times_used': 3125254,
#    'tool_call_errors': 3613,
#    'total_completion_tokens': 1220120548,
#    'total_native_reasoning_tokens': 443505760,
#    'total_prompt_tokens': 20901700460,
#    'total_tool_calls': 175966}]}

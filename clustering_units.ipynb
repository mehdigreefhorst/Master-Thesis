# %%
from local_host_tester import app

# %%
data = app.get("/experiment/get_sample_units_labeling_format?scraper_cluster_id=6936c92ac25a6f344fc48b69&filter_label_template_id=6953891c65345d1a9a51c976").json()

# %%
for i in range(30):
  print(data.get("experiment_unit_data")[i].get("errors"))
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[32], line 2
#       1 for i in range(30):
# ----> 2   print(data.get("experiment_unit_data")[i].get("errors"))
#
# IndexError: list index out of range

# %%
data.get("experiment_unit_data")[8].keys()
# Out:
# dict_keys(['cluster_unit_enity', 'errors', 'label_name_predicted_data'])

# %%
import json

# %%
data = """"""

# %%
json.loads(data)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 json.loads(data)
#
# File /opt/homebrew/Cellar/python@3.12/3.12.10/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /opt/homebrew/Cellar/python@3.12/3.12.10/Frameworks/Python.framework/Versions/3.12/lib/python3.12/json/decoder.py:338, in JSONDecoder.decode(self, s, _w)
# ...

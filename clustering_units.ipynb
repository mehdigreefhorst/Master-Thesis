# %%
from local_host_tester import app

# %%
app.delete("/experiment?experiment_id=69513cede0bb9fd14cbfcc23", {"experiment_id": "69513cede0bb9fd14cbfcc23"}).json()
# Out:
# {'message': 'Succesfully deleted 0 experiments with id = 69513cede0bb9fd14cbfcc23'}

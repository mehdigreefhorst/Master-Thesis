# %%
from local_host_tester import app

# %%
app.post("/experiment/test/prediction", json_data={
    "experiment_id": "693c3fefc0efcac68873f9f5",
    "label_template_id": "693ac04ab38ec9eae957e3a8",
    "cluster_unit_ids": ["6939e382216f00e87c009edd", "6939e355216f00e87c008ee4"]

}).json()
# Out:
# {'message': 'No experiment entity found for experiment id : 693c3cdc56af314ba85121d0'}

# %%
app.put("/clustering/update_ground_truth_per_label", json_data={
      "label_template_id": "693ac04ab38ec9eae957e3a8",
    "cluster_unit_entity_id": "6939e382216f00e87c009edd",
    "ground_truth_one_shot_example": {
      "problem_description": {
        "value": True,
        "label": "problem_description",
        "type": "boolean",
        "per_label_details": [{
          "value": "the best reason in the wrold",
          "label": "reason",
          "type": "string",
        }]
      }
    }
}).json()
# Out:
# {'result': 1}
